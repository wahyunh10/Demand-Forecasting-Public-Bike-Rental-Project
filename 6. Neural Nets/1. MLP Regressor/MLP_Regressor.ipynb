# %% [markdown]
# <a href="https://colab.research.google.com/github/wahyunh10/Demand-Forecasting-Public-Bike-Rental-Project/blob/main/MLP_Regressor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Artificial Neural Networks: Multi Layer Perceptron Regressor**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("cleandata.csv", index_col='datetime', parse_dates=True)
df.head()
# Out:
#                      month  hour  season  holiday  workingday  weather  temp  \
# datetime
# 2011-01-01 00:00:00      1     0       1        0           0        1  9.84
# 2011-01-01 01:00:00      1     1       1        0           0        1  9.02
# 2011-01-01 02:00:00      1     2       1        0           0        1  9.02
# 2011-01-01 03:00:00      1     3       1        0           0        1  9.84
# 2011-01-01 04:00:00      1     4       1        0           0        1  9.84
#
#                       atemp  humidity  windspeed  casual  registered  rentals
# datetime
# 2011-01-01 00:00:00  14.395        81        0.0       3          13       16
# 2011-01-01 01:00:00  13.635        80        0.0       8          32       40
# 2011-01-01 02:00:00  13.635        80        0.0       5          27       32
# 2011-01-01 03:00:00  14.395        75        0.0       3          10       13
# 2011-01-01 04:00:00  14.395        75        0.0       0           1        1

# %%
dfc = df.copy()
dfc.head()
# Out:
#                      month  hour  season  holiday  workingday  weather  temp  \
# datetime
# 2011-01-01 00:00:00      1     0       1        0           0        1  9.84
# 2011-01-01 01:00:00      1     1       1        0           0        1  9.02
# 2011-01-01 02:00:00      1     2       1        0           0        1  9.02
# 2011-01-01 03:00:00      1     3       1        0           0        1  9.84
# 2011-01-01 04:00:00      1     4       1        0           0        1  9.84
#
#                       atemp  humidity  windspeed  casual  registered  rentals
# datetime
# 2011-01-01 00:00:00  14.395        81        0.0       3          13       16
# 2011-01-01 01:00:00  13.635        80        0.0       8          32       40
# 2011-01-01 02:00:00  13.635        80        0.0       5          27       32
# 2011-01-01 03:00:00  14.395        75        0.0       3          10       13
# 2011-01-01 04:00:00  14.395        75        0.0       0           1        1

# %%
dfc
# Out:
#                      month  hour  season  holiday  workingday  weather   temp  \
# datetime
# 2011-01-01 00:00:00      1     0       1        0           0        1   9.84
# 2011-01-01 01:00:00      1     1       1        0           0        1   9.02
# 2011-01-01 02:00:00      1     2       1        0           0        1   9.02
# 2011-01-01 03:00:00      1     3       1        0           0        1   9.84
# 2011-01-01 04:00:00      1     4       1        0           0        1   9.84
# ...                    ...   ...     ...      ...         ...      ...    ...
# 2012-12-19 19:00:00     12    19       4        0           1        1  15.58
# 2012-12-19 20:00:00     12    20       4        0           1        1  14.76
# 2012-12-19 21:00:00     12    21       4        0           1        1  13.94
# 2012-12-19 22:00:00     12    22       4        0           1        1  13.94
# 2012-12-19 23:00:00     12    23       4        0           1        1  13.12
#
#                       atemp  humidity  windspeed  casual  registered  rentals
# datetime
# 2011-01-01 00:00:00  14.395        81     0.0000       3          13       16
# 2011-01-01 01:00:00  13.635        80     0.0000       8          32       40
# 2011-01-01 02:00:00  13.635        80     0.0000       5          27       32
# 2011-01-01 03:00:00  14.395        75     0.0000       3          10       13
# 2011-01-01 04:00:00  14.395        75     0.0000       0           1        1
# ...                     ...       ...        ...     ...         ...      ...
# 2012-12-19 19:00:00  19.695        50    26.0027       7         329      336
# 2012-12-19 20:00:00  17.425        57    15.0013      10         231      241
# 2012-12-19 21:00:00  15.910        61    15.0013       4         164      168
# 2012-12-19 22:00:00  17.425        61     6.0032      12         117      129
# 2012-12-19 23:00:00  16.665        66     8.9981       4          84       88
#
# [10348 rows x 13 columns]

# %%
dummy_season = pd.get_dummies(dfc.season, prefix='season')
dummy_season.sample(n=10,random_state = 12)
# Out:
#                      season_1  season_2  season_3  season_4
# datetime
# 2012-01-10 12:00:00         1         0         0         0
# 2011-03-03 16:00:00         1         0         0         0
# 2011-11-05 16:00:00         0         0         0         1
# 2012-12-08 17:00:00         0         0         0         1
# 2011-06-10 17:00:00         0         1         0         0
# 2011-08-13 09:00:00         0         0         1         0
# 2012-01-01 12:00:00         1         0         0         0
# 2012-08-04 05:00:00         0         0         1         0
# 2011-12-17 16:00:00         0         0         0         1
# 2012-04-01 08:00:00         0         1         0         0

# %%
dummy_weather = pd.get_dummies(dfc.weather, prefix='weather')
dummy_weather.sample(n=10, random_state = 12)
# Out:
#                      weather_1  weather_2  weather_3  weather_4
# datetime
# 2012-01-10 12:00:00          1          0          0          0
# 2011-03-03 16:00:00          1          0          0          0
# 2011-11-05 16:00:00          1          0          0          0
# 2012-12-08 17:00:00          1          0          0          0
# 2011-06-10 17:00:00          1          0          0          0
# 2011-08-13 09:00:00          0          1          0          0
# 2012-01-01 12:00:00          1          0          0          0
# 2012-08-04 05:00:00          1          0          0          0
# 2011-12-17 16:00:00          1          0          0          0
# 2012-04-01 08:00:00          0          1          0          0

# %%
dummy_hour = pd.get_dummies(dfc.hour, prefix='hour')
dummy_hour.sample(n=10, random_state = 12)
# Out:
#                      hour_0  hour_1  hour_2  hour_3  hour_4  hour_5  hour_6  \
# datetime
# 2012-01-10 12:00:00       0       0       0       0       0       0       0
# 2011-03-03 16:00:00       0       0       0       0       0       0       0
# 2011-11-05 16:00:00       0       0       0       0       0       0       0
# 2012-12-08 17:00:00       0       0       0       0       0       0       0
# 2011-06-10 17:00:00       0       0       0       0       0       0       0
# 2011-08-13 09:00:00       0       0       0       0       0       0       0
# 2012-01-01 12:00:00       0       0       0       0       0       0       0
# 2012-08-04 05:00:00       0       0       0       0       0       1       0
# 2011-12-17 16:00:00       0       0       0       0       0       0       0
# 2012-04-01 08:00:00       0       0       0       0       0       0       0
#
#                      hour_7  hour_8  hour_9  ...  hour_14  hour_15  hour_16  \
# datetime                                     ...
# 2012-01-10 12:00:00       0       0       0  ...        0        0        0
# 2011-03-03 16:00:00       0       0       0  ...        0        0        1
# 2011-11-05 16:00:00       0       0       0  ...        0        0        1
# 2012-12-08 17:00:00       0       0       0  ...        0        0        0
# 2011-06-10 17:00:00       0       0       0  ...        0        0        0
# 2011-08-13 09:00:00       0       0       1  ...        0        0        0
# 2012-01-01 12:00:00       0       0       0  ...        0        0        0
# 2012-08-04 05:00:00       0       0       0  ...        0        0        0
# 2011-12-17 16:00:00       0       0       0  ...        0        0        1
# 2012-04-01 08:00:00       0       1       0  ...        0        0        0
#
#                      hour_17  hour_18  hour_19  hour_20  hour_21  hour_22  \
# datetime
# 2012-01-10 12:00:00        0        0        0        0        0        0
# 2011-03-03 16:00:00        0        0        0        0        0        0
# 2011-11-05 16:00:00        0        0        0        0        0        0
# 2012-12-08 17:00:00        1        0        0        0        0        0
# 2011-06-10 17:00:00        1        0        0        0        0        0
# 2011-08-13 09:00:00        0        0        0        0        0        0
# 2012-01-01 12:00:00        0        0        0        0        0        0
# 2012-08-04 05:00:00        0        0        0        0        0        0
# 2011-12-17 16:00:00        0        0        0        0        0        0
# 2012-04-01 08:00:00        0        0        0        0        0        0
#
#                      hour_23
# datetime
# 2012-01-10 12:00:00        0
# 2011-03-03 16:00:00        0
# 2011-11-05 16:00:00        0
# 2012-12-08 17:00:00        0
# 2011-06-10 17:00:00        0
# 2011-08-13 09:00:00        0
# 2012-01-01 12:00:00        0
# 2012-08-04 05:00:00        0
# 2011-12-17 16:00:00        0
# 2012-04-01 08:00:00        0
#
# [10 rows x 24 columns]

# %%
dfc = pd.concat([dfc, dummy_hour], axis=1)
dfc = pd.concat([dfc, dummy_weather], axis=1)
dfc = pd.concat([dfc, dummy_season], axis=1)

# %%
dfc.head(10)
# Out:
#                      month  hour  season  holiday  workingday  weather   temp  \
# datetime
# 2011-01-01 00:00:00      1     0       1        0           0        1   9.84
# 2011-01-01 01:00:00      1     1       1        0           0        1   9.02
# 2011-01-01 02:00:00      1     2       1        0           0        1   9.02
# 2011-01-01 03:00:00      1     3       1        0           0        1   9.84
# 2011-01-01 04:00:00      1     4       1        0           0        1   9.84
# 2011-01-01 05:00:00      1     5       1        0           0        2   9.84
# 2011-01-01 06:00:00      1     6       1        0           0        1   9.02
# 2011-01-01 07:00:00      1     7       1        0           0        1   8.20
# 2011-01-01 08:00:00      1     8       1        0           0        1   9.84
# 2011-01-01 09:00:00      1     9       1        0           0        1  13.12
#
#                       atemp  humidity  windspeed  ...  hour_22  hour_23  \
# datetime                                          ...
# 2011-01-01 00:00:00  14.395        81     0.0000  ...        0        0
# 2011-01-01 01:00:00  13.635        80     0.0000  ...        0        0
# 2011-01-01 02:00:00  13.635        80     0.0000  ...        0        0
# 2011-01-01 03:00:00  14.395        75     0.0000  ...        0        0
# 2011-01-01 04:00:00  14.395        75     0.0000  ...        0        0
# 2011-01-01 05:00:00  12.880        75     6.0032  ...        0        0
# 2011-01-01 06:00:00  13.635        80     0.0000  ...        0        0
# 2011-01-01 07:00:00  12.880        86     0.0000  ...        0        0
# 2011-01-01 08:00:00  14.395        75     0.0000  ...        0        0
# 2011-01-01 09:00:00  17.425        76     0.0000  ...        0        0
#
#                      weather_1  weather_2  weather_3  weather_4  season_1  \
# datetime
# 2011-01-01 00:00:00          1          0          0          0         1
# 2011-01-01 01:00:00          1          0          0          0         1
# 2011-01-01 02:00:00          1          0          0          0         1
# 2011-01-01 03:00:00          1          0          0          0         1
# 2011-01-01 04:00:00          1          0          0          0         1
# 2011-01-01 05:00:00          0          1          0          0         1
# 2011-01-01 06:00:00          1          0          0          0         1
# 2011-01-01 07:00:00          1          0          0          0         1
# 2011-01-01 08:00:00          1          0          0          0         1
# 2011-01-01 09:00:00          1          0          0          0         1
#
#                      season_2  season_3  season_4
# datetime
# 2011-01-01 00:00:00         0         0         0
# 2011-01-01 01:00:00         0         0         0
# 2011-01-01 02:00:00         0         0         0
# 2011-01-01 03:00:00         0         0         0
# 2011-01-01 04:00:00         0         0         0
# 2011-01-01 05:00:00         0         0         0
# 2011-01-01 06:00:00         0         0         0
# 2011-01-01 07:00:00         0         0         0
# 2011-01-01 08:00:00         0         0         0
# 2011-01-01 09:00:00         0         0         0
#
# [10 rows x 45 columns]

# %%
dfc.drop(['hour','season','weather','atemp','casual','registered'], axis = 1, inplace=True)
dfc.head(20)
# Out:
#                      month  holiday  workingday   temp  humidity  windspeed  \
# datetime
# 2011-01-01 00:00:00      1        0           0   9.84        81     0.0000
# 2011-01-01 01:00:00      1        0           0   9.02        80     0.0000
# 2011-01-01 02:00:00      1        0           0   9.02        80     0.0000
# 2011-01-01 03:00:00      1        0           0   9.84        75     0.0000
# 2011-01-01 04:00:00      1        0           0   9.84        75     0.0000
# 2011-01-01 05:00:00      1        0           0   9.84        75     6.0032
# 2011-01-01 06:00:00      1        0           0   9.02        80     0.0000
# 2011-01-01 07:00:00      1        0           0   8.20        86     0.0000
# 2011-01-01 08:00:00      1        0           0   9.84        75     0.0000
# 2011-01-01 09:00:00      1        0           0  13.12        76     0.0000
# 2011-01-01 10:00:00      1        0           0  15.58        76    16.9979
# 2011-01-01 11:00:00      1        0           0  14.76        81    19.0012
# 2011-01-01 12:00:00      1        0           0  17.22        77    19.0012
# 2011-01-01 13:00:00      1        0           0  18.86        72    19.9995
# 2011-01-01 14:00:00      1        0           0  18.86        72    19.0012
# 2011-01-01 15:00:00      1        0           0  18.04        77    19.9995
# 2011-01-01 16:00:00      1        0           0  17.22        82    19.9995
# 2011-01-01 17:00:00      1        0           0  18.04        82    19.0012
# 2011-01-01 18:00:00      1        0           0  17.22        88    16.9979
# 2011-01-01 19:00:00      1        0           0  17.22        88    16.9979
#
#                      rentals  hour_0  hour_1  hour_2  ...  hour_22  hour_23  \
# datetime                                              ...
# 2011-01-01 00:00:00       16       1       0       0  ...        0        0
# 2011-01-01 01:00:00       40       0       1       0  ...        0        0
# 2011-01-01 02:00:00       32       0       0       1  ...        0        0
# 2011-01-01 03:00:00       13       0       0       0  ...        0        0
# 2011-01-01 04:00:00        1       0       0       0  ...        0        0
# 2011-01-01 05:00:00        1       0       0       0  ...        0        0
# 2011-01-01 06:00:00        2       0       0       0  ...        0        0
# 2011-01-01 07:00:00        3       0       0       0  ...        0        0
# 2011-01-01 08:00:00        8       0       0       0  ...        0        0
# 2011-01-01 09:00:00       14       0       0       0  ...        0        0
# 2011-01-01 10:00:00       36       0       0       0  ...        0        0
# 2011-01-01 11:00:00       56       0       0       0  ...        0        0
# 2011-01-01 12:00:00       84       0       0       0  ...        0        0
# 2011-01-01 13:00:00       94       0       0       0  ...        0        0
# 2011-01-01 14:00:00      106       0       0       0  ...        0        0
# 2011-01-01 15:00:00      110       0       0       0  ...        0        0
# 2011-01-01 16:00:00       93       0       0       0  ...        0        0
# 2011-01-01 17:00:00       67       0       0       0  ...        0        0
# 2011-01-01 18:00:00       35       0       0       0  ...        0        0
# 2011-01-01 19:00:00       37       0       0       0  ...        0        0
#
#                      weather_1  weather_2  weather_3  weather_4  season_1  \
# datetime
# 2011-01-01 00:00:00          1          0          0          0         1
# 2011-01-01 01:00:00          1          0          0          0         1
# 2011-01-01 02:00:00          1          0          0          0         1
# 2011-01-01 03:00:00          1          0          0          0         1
# 2011-01-01 04:00:00          1          0          0          0         1
# 2011-01-01 05:00:00          0          1          0          0         1
# 2011-01-01 06:00:00          1          0          0          0         1
# 2011-01-01 07:00:00          1          0          0          0         1
# 2011-01-01 08:00:00          1          0          0          0         1
# 2011-01-01 09:00:00          1          0          0          0         1
# 2011-01-01 10:00:00          1          0          0          0         1
# 2011-01-01 11:00:00          1          0          0          0         1
# 2011-01-01 12:00:00          1          0          0          0         1
# 2011-01-01 13:00:00          0          1          0          0         1
# 2011-01-01 14:00:00          0          1          0          0         1
# 2011-01-01 15:00:00          0          1          0          0         1
# 2011-01-01 16:00:00          0          1          0          0         1
# 2011-01-01 17:00:00          0          1          0          0         1
# 2011-01-01 18:00:00          0          0          1          0         1
# 2011-01-01 19:00:00          0          0          1          0         1
#
#                      season_2  season_3  season_4
# datetime
# 2011-01-01 00:00:00         0         0         0
# 2011-01-01 01:00:00         0         0         0
# 2011-01-01 02:00:00         0         0         0
# 2011-01-01 03:00:00         0         0         0
# 2011-01-01 04:00:00         0         0         0
# 2011-01-01 05:00:00         0         0         0
# 2011-01-01 06:00:00         0         0         0
# 2011-01-01 07:00:00         0         0         0
# 2011-01-01 08:00:00         0         0         0
# 2011-01-01 09:00:00         0         0         0
# 2011-01-01 10:00:00         0         0         0
# 2011-01-01 11:00:00         0         0         0
# 2011-01-01 12:00:00         0         0         0
# 2011-01-01 13:00:00         0         0         0
# 2011-01-01 14:00:00         0         0         0
# 2011-01-01 15:00:00         0         0         0
# 2011-01-01 16:00:00         0         0         0
# 2011-01-01 17:00:00         0         0         0
# 2011-01-01 18:00:00         0         0         0
# 2011-01-01 19:00:00         0         0         0
#
# [20 rows x 39 columns]

# %%
dfc.columns
# Out:
# Index(['month', 'holiday', 'workingday', 'temp', 'humidity', 'windspeed',
#        'rentals', 'hour_0', 'hour_1', 'hour_2', 'hour_3', 'hour_4', 'hour_5',
#        'hour_6', 'hour_7', 'hour_8', 'hour_9', 'hour_10', 'hour_11', 'hour_12',
#        'hour_13', 'hour_14', 'hour_15', 'hour_16', 'hour_17', 'hour_18',
#        'hour_19', 'hour_20', 'hour_21', 'hour_22', 'hour_23', 'weather_1',
#        'weather_2', 'weather_3', 'weather_4', 'season_1', 'season_2',
#        'season_3', 'season_4'],
#       dtype='object')

# %%
X = dfc[['temp','hour_0', 'hour_1', 'hour_2', 'hour_3', 'hour_4', 'hour_5', 'hour_6',
       'hour_7', 'hour_8', 'hour_9', 'hour_10', 'hour_11', 'hour_12',
       'hour_13', 'hour_14', 'hour_15', 'hour_16', 'hour_17', 'hour_18',
       'hour_19', 'hour_20', 'hour_21', 'hour_22', 'hour_23','weather_1',
       'weather_2', 'weather_3', 'weather_4', 'season_1', 'season_2',
       'season_3', 'season_4']]

# %%
X.columns
# Out:
# Index(['temp', 'hour_0', 'hour_1', 'hour_2', 'hour_3', 'hour_4', 'hour_5',
#        'hour_6', 'hour_7', 'hour_8', 'hour_9', 'hour_10', 'hour_11', 'hour_12',
#        'hour_13', 'hour_14', 'hour_15', 'hour_16', 'hour_17', 'hour_18',
#        'hour_19', 'hour_20', 'hour_21', 'hour_22', 'hour_23', 'weather_1',
#        'weather_2', 'weather_3', 'weather_4', 'season_1', 'season_2',
#        'season_3', 'season_4'],
#       dtype='object')

# %% [markdown]
# # **Scaling the Features using STD SCALER**

# %%
from sklearn.preprocessing import StandardScaler
X_scaled = StandardScaler().fit_transform(X) # Standardization Technique

# %%
y = dfc[['rentals']]

# %%
from sklearn import metrics
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled,y, test_size=0.25, random_state=100)

# %% [markdown]
# # **Base Model Building Using sklearn.neural_network library**

# %%
from sklearn.neural_network import MLPRegressor
regressor = MLPRegressor(hidden_layer_sizes=(25), max_iter=300, random_state = 0) 
regressor.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:1599: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:696: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   ConvergenceWarning,
# MLPRegressor(hidden_layer_sizes=25, max_iter=300, random_state=0)

# %%
predicted = regressor.predict(X_test)
predicted
# Out:
# array([ 78.85326538, 398.5410613 ,   9.84570777, ...,  47.5283079 ,
#        478.20279359,  80.59493365])

# %% [markdown]
# # **MAE**

# %%
metrics.mean_absolute_error(y_test,predicted)
# Out:
# 61.243897529272466

# %% [markdown]
# # **MSE**

# %%
metrics.mean_squared_error(y_test,predicted)
# Out:
# 7916.411871144713

# %% [markdown]
# # **RMSE**

# %%
np.sqrt(metrics.mean_squared_error(y_test,predicted))
# Out:
# 88.97422026151571

# %% [markdown]
# # **MLP using GridSearch Cross Calidation**
# **Hyper Parameter Tuning**
#
# We can calculate the best parameters for the model using “GridSearchCV”. The input parameters for the GridSearchCV method are
#
# The MLP model
# A parameter dictionary in which we define various hidden layers, activation units, learning rates.
# It trains the model and finds the best parameter.

# %%
from sklearn.neural_network import MLPRegressor
from sklearn.model_selection import GridSearchCV # Cross Validation Technique: Grid Search 
mlpregressor = MLPRegressor(random_state=1, max_iter=100) # Create a base regressor
mlpregressor.fit(X_train,y_train) 
mlpregressor
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:1599: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:696: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   ConvergenceWarning,
# MLPRegressor(max_iter=100, random_state=1)

# %%
# Parameter Dictionary in which we define various parameters:
check_parameters = {
    'hidden_layer_sizes': [(24),(24,12), (24,12,6)],
    'activation': ['logistic','tanh'],
    'solver': ['sgd', 'adam'],
    'alpha': [0.0001, 0.05],
    'learning_rate': ['constant','adaptive'],
}

# %%
# Create variable gridsearchcv and feed in the necessary inputs:
gridsearchcv = GridSearchCV(mlpregressor, check_parameters, n_jobs=-1, cv=3)
gridsearchcv.fit(X_train, y_train) # Fit the model to the training dataset.
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:1599: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:696: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   ConvergenceWarning,
# GridSearchCV(cv=3, estimator=MLPRegressor(max_iter=100, random_state=1),
#              n_jobs=-1,
#              param_grid={'activation': ['logistic', 'tanh'],
#                          'alpha': [0.0001, 0.05],
#                          'hidden_layer_sizes': [24, (24, 12), (24, 12, 6)],
#                          'learning_rate': ['constant', 'adaptive'],
#                          'solver': ['sgd', 'adam']})

# %%
print('Best parameters found:\n', gridsearchcv.best_params_)
# Out:
# Best parameters found:
#  {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': 24, 'learning_rate': 'constant', 'solver': 'sgd'}

# %%
mlpregressor1 = MLPRegressor(activation='logistic', alpha=1e-4, hidden_layer_sizes=(24), learning_rate='constant', solver='sgd', max_iter=400, random_state=1,verbose=10)
mlpregressor1.fit(X_train,y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:1599: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Iteration 1, loss = 11431.62521916
# Iteration 2, loss = 4636.12418005
# Iteration 3, loss = 4339.61980685
# Iteration 4, loss = 4185.42462349
# Iteration 5, loss = 4139.66201619
# Iteration 6, loss = 4104.32859391
# Iteration 7, loss = 4041.54682616
# Iteration 8, loss = 4021.56458683
# Iteration 9, loss = 4002.30147250
# Iteration 10, loss = 3982.18698978
# Iteration 11, loss = 3977.12178518
# Iteration 12, loss = 3957.58659273
# Iteration 13, loss = 3952.32563359
# Iteration 14, loss = 3927.00265617
# Iteration 15, loss = 3932.26373837
# Iteration 16, loss = 3914.44643928
# Iteration 17, loss = 3910.86151121
# Iteration 18, loss = 3892.72448096
# Iteration 19, loss = 3890.82625317
# Iteration 20, loss = 3879.88959900
# Iteration 21, loss = 3877.62108189
# Iteration 22, loss = 3870.34981922
# Iteration 23, loss = 3864.19976334
# Iteration 24, loss = 3866.43864420
# Iteration 25, loss = 3854.46550696
# Iteration 26, loss = 3848.34920500
# Iteration 27, loss = 3847.45401460
# Iteration 28, loss = 3844.53997188
# Iteration 29, loss = 3831.45729380
# Iteration 30, loss = 3826.72886116
# Iteration 31, loss = 3827.70750511
# Iteration 32, loss = 3817.60368072
# Iteration 33, loss = 3810.70587025
# Iteration 34, loss = 3814.80466288
# Iteration 35, loss = 3819.21429974
# Iteration 36, loss = 3801.89257474
# Iteration 37, loss = 3801.85976529
# Iteration 38, loss = 3802.37812100
# Iteration 39, loss = 3793.68304835
# Iteration 40, loss = 3791.44609879
# Iteration 41, loss = 3798.46429914
# Iteration 42, loss = 3788.66745230
# Iteration 43, loss = 3783.42386442
# Iteration 44, loss = 3786.44965888
# Iteration 45, loss = 3773.61346555
# Iteration 46, loss = 3786.91345672
# Iteration 47, loss = 3775.69049243
# Iteration 48, loss = 3771.23149625
# Iteration 49, loss = 3775.65566372
# Iteration 50, loss = 3772.53053749
# Iteration 51, loss = 3763.48828499
# Iteration 52, loss = 3780.33153456
# Iteration 53, loss = 3766.99935882
# Iteration 54, loss = 3756.04629551
# Iteration 55, loss = 3766.73627828
# Iteration 56, loss = 3758.32046581
# Iteration 57, loss = 3764.19437082
# Iteration 58, loss = 3774.39897605
# Iteration 59, loss = 3746.62057950
# Iteration 60, loss = 3749.42378718
# Iteration 61, loss = 3748.59931277
# Iteration 62, loss = 3748.64931170
# Iteration 63, loss = 3742.41421152
# Iteration 64, loss = 3745.85525199
# Iteration 65, loss = 3754.84028058
# Iteration 66, loss = 3733.71159205
# Iteration 67, loss = 3747.14781480
# Iteration 68, loss = 3745.40738606
# Iteration 69, loss = 3739.47817152
# Iteration 70, loss = 3726.17939853
# Iteration 71, loss = 3731.99246408
# Iteration 72, loss = 3727.96469851
# Iteration 73, loss = 3729.32804080
# Iteration 74, loss = 3721.94230434
# Iteration 75, loss = 3728.59744881
# Iteration 76, loss = 3725.15606528
# Iteration 77, loss = 3727.81674319
# Iteration 78, loss = 3718.40644721
# Iteration 79, loss = 3723.27068382
# Iteration 80, loss = 3718.25743033
# Iteration 81, loss = 3721.38519003
# Iteration 82, loss = 3724.11394149
# Iteration 83, loss = 3728.82385308
# Iteration 84, loss = 3718.19956201
# Iteration 85, loss = 3716.08438470
# Iteration 86, loss = 3720.60712749
# Iteration 87, loss = 3712.32941522
# Iteration 88, loss = 3711.37487560
# Iteration 89, loss = 3713.69005193
# Iteration 90, loss = 3709.10410958
# Iteration 91, loss = 3709.90137134
# Iteration 92, loss = 3705.84945317
# Iteration 93, loss = 3699.73548996
# Iteration 94, loss = 3704.02350639
# Iteration 95, loss = 3715.08780010
# Iteration 96, loss = 3701.77272580
# Iteration 97, loss = 3701.97615920
# Iteration 98, loss = 3703.74232270
# Iteration 99, loss = 3696.28417762
# Iteration 100, loss = 3698.94235644
# Iteration 101, loss = 3695.31924229
# Iteration 102, loss = 3699.09322711
# Iteration 103, loss = 3693.39392853
# Iteration 104, loss = 3701.34507959
# Iteration 105, loss = 3689.32071084
# Iteration 106, loss = 3690.61260317
# Iteration 107, loss = 3685.72039102
# Iteration 108, loss = 3692.65331831
# Iteration 109, loss = 3693.62165519
# Iteration 110, loss = 3689.23101582
# Iteration 111, loss = 3691.16709368
# Iteration 112, loss = 3697.22678679
# Iteration 113, loss = 3685.28122406
# Iteration 114, loss = 3686.04582111
# Iteration 115, loss = 3683.79816350
# Iteration 116, loss = 3681.28851935
# Iteration 117, loss = 3686.46061573
# Iteration 118, loss = 3684.87272762
# Iteration 119, loss = 3682.00526324
# Iteration 120, loss = 3680.77966640
# Iteration 121, loss = 3675.63148040
# Iteration 122, loss = 3683.16498699
# Iteration 123, loss = 3684.28302334
# Iteration 124, loss = 3680.73261952
# Iteration 125, loss = 3688.90104363
# Iteration 126, loss = 3674.74975066
# Iteration 127, loss = 3681.86572545
# Iteration 128, loss = 3669.76530457
# Iteration 129, loss = 3677.62564722
# Iteration 130, loss = 3684.82661700
# Iteration 131, loss = 3676.26443405
# Iteration 132, loss = 3673.19354994
# Iteration 133, loss = 3672.77588659
# Iteration 134, loss = 3676.91543221
# Iteration 135, loss = 3665.48717202
# Iteration 136, loss = 3677.24463780
# Iteration 137, loss = 3668.86349910
# Iteration 138, loss = 3670.31150208
# Iteration 139, loss = 3674.49206230
# Iteration 140, loss = 3664.85216070
# Iteration 141, loss = 3668.61867248
# Iteration 142, loss = 3671.45272855
# Iteration 143, loss = 3664.74373194
# Iteration 144, loss = 3672.57454110
# Iteration 145, loss = 3663.45257472
# Iteration 146, loss = 3656.91621735
# Iteration 147, loss = 3665.72812543
# Iteration 148, loss = 3667.04534481
# Iteration 149, loss = 3665.67410958
# Iteration 150, loss = 3659.31533458
# Iteration 151, loss = 3668.35075834
# Iteration 152, loss = 3666.46498754
# Iteration 153, loss = 3661.89629237
# Iteration 154, loss = 3667.36498766
# Iteration 155, loss = 3661.87671412
# Iteration 156, loss = 3657.83177452
# Iteration 157, loss = 3663.68850872
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# MLPRegressor(activation='logistic', hidden_layer_sizes=24, max_iter=400,
#              random_state=1, solver='sgd', verbose=10)

# %%
predicted1 = mlpregressor1.predict(X_test)
predicted1
# Out:
# array([ 75.48748881, 411.6522817 ,   1.03588827, ...,  62.93571894,
#        463.10925684,  78.91339401])

# %% [markdown]
# # **Performance Evaluation of Optimal Model**

# %%
print(metrics.mean_absolute_error(y_test,predicted1))
print(metrics.mean_squared_error(y_test,predicted1))
print(np.sqrt(metrics.mean_squared_error(y_test,predicted1)))
# Out:
# 60.944369038028206
# 7850.36150521892
# 88.60226580183443

# %%
new_df=y_test.copy()
new_df['pred']=predicted1
new_df=new_df.sort_index()
new_df
# Out:
#                      rentals        pred
# datetime
# 2011-01-01 01:00:00       40   34.253336
# 2011-01-01 03:00:00       13    0.973426
# 2011-01-01 12:00:00       84  199.033509
# 2011-01-01 21:00:00       34  113.222277
# 2011-01-01 22:00:00       28   75.957831
# ...                      ...         ...
# 2012-12-19 04:00:00        7    2.613005
# 2012-12-19 10:00:00      164  176.282093
# 2012-12-19 17:00:00      562  462.957072
# 2012-12-19 18:00:00      569  394.593545
# 2012-12-19 20:00:00      241  207.554485
#
# [2587 rows x 2 columns]

# %%
plt.figure(figsize=(18, 6))
plt.plot(new_df['pred'][0:500])
plt.plot(new_df['rentals'][0:500])
plt.title('MLP Regressor Regressor - Forecast vs Actual Record')
plt.xlabel('DateTime',fontsize=15)
plt.ylabel('Value of Bike Rental',fontsize=15)
# Out:
# Text(0, 0.5, 'Value of Bike Rental')
